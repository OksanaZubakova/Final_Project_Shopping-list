# %%
korean = {
    'bibimbap':['rice', 'beef', 'spinach', 'soy sauce','sesame oil','brown sugar','garlic','shiitake mushroom','carrots', 'eggs'],
    "kimchi": ['napa cabbage','salt', 'sweet rice flour', 'sugar', 'daikon radish', 'green onion','asian chives', 'garlic', 'ginger', 'red pepper flakes'],
    "roll": ['rice', 'seeweed sheets', 'seasam oil', 'spinach', 'egg','carrot', 'yellow radish pickle']
}
chinese  = {
    "hunan shrimp": ['shrimp','bell pepper','ginger','garlic','green onion','green beans'],
    "egg soup":['ground pork', 'ginger', 'garlic','green onions', 'onion', 'carrots', 'cabbage','soy sauce','sriracha','sesame seeds'],
    "wonton soup": ['frozen wontons','shallots','ginger','garlic','shiitake mushrooms','bok choy','scallions','chicken broth', 'oil']
    }

thai = {
    "noodle soup" :['coconut oil', "desiree potatoes", "onion", "yellow curry paste", "coconut milk", "chicken stock", "fish sauce", "dried rice noodles", "baby spinach"],
    "pad thai": ["dried rice sticks", "tamarind puree", "brown sugar", "fish sauce", "oyster sauce", "onion","garlic cloves", "chicken breast", "eggs", "beansprouts", "tofu"],
    "tom yum" : ["shrimps","makrut lime leaves", "lemongrass","galangal","thai chilies taste", "fresh lime juice", "fish sauce", "sugar", "mushrooms", "cilantro"]
}

japanese = {
    "kakuni bossam": ["oil", "boneless pork belly","cooking sake", "soy sauce", "mirin", "brown sugar", 'oroshi ginger',"eggs"],
    'miso soup': ["kombu", 'katsuobushi', "silken tofu", "miso paste", "dashi", "dried wakame seaweed", "green onion"],
    'mochi' : ["sweetened red bean paste", "red raspberries", "glutinous rice flour", "green tea powder", "water" , "white sugar", "cornstarch"]
}

cuisine = {
  "korean" : korean,
  "chinese" : chinese,
  "japanese" : japanese,
  "thai": thai
}

def choose_meal(food):
  print()
  print("Here are the meals we have available: ")
  for keys in food:
    print(keys)   
  print()
  dish = input('Please choose the meal from the list above: ')
  dish = dish.lower()
  while dish not in food:
    dish=input ('Sorry. We do not know this meal. Choose another one: ') 
  print()
  print('Great. Here is your list:' )
  print()
  for i in food[dish]:
    print (i)

print("Dear fan of Asian food,\nWe are happy that you have chosen our App.\nWe can help you to create a shopping list. We have recipes of following cuisine :")
print()
for keys, value in cuisine.items():
   print(keys)
print()

new_food = 'Y'
while new_food == 'Y':

  food = input('What is your favourite cuisine : ')
  food = food.lower()
  while food not in cuisine:
    food = input('Unfornutetlly, the your food is not available. Please pick from the list above: ')
  else:
    choose_meal(cuisine[food])
  print()

  new_food =input('Do you want choose another meal (Y/N)?')
  print()
else:
  print()
  print('\033[1m' + "Thank you for choosing us!"+'\033[0m')
# Out:
# Dear fan of Asian food,
# We are happy that you have chosen our App.
# We can help you to create a shopping list. We have recipes of following cuisine :
#
# korean
# chinese
# japanese
# thai
#
# What is your favourite cuisine : thai
#
# Here are the meals we have available:
# noodle soup
# pad thai
# tom yum
